# %% [markdown]
# <a href="https://colab.research.google.com/github/CS112-L21-KHTN-N2/Homework/blob/main/Analysis%20of%20Algorithms/AnalysisAlgorithm_N2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bài 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Chọn C. Vì BigO được sử dụng để xác định cận trên của thuật toán => Có thể xác định trường hợp xấu nhất.

# %% [markdown]
# #Bài 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Độ phức tạp = O($\frac{n}{2} + \frac{n}{4} +\frac{n}{8} +...$) = O(n)

# %% [markdown]
# #Bài 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ta có quan hệ đệ quy DoSomething() là: T($\sqrt{n}$) + c nếu n > 2 (1)
#
# Cho: n = $2^{m}$ => (1) trở thành T($\sqrt{2^{m}}$) + c = T($2^{\frac{m}{2}}$)
#
# Đặt: T($2^{m}$) = S(m) (2) => T(n) = S(m)
#
# (2) <=> T($2^{\frac{m}{2}}$) = S($\frac{m}{2}$)
#
# Xét S($\frac{m}{2}$), ta có: a = 1, b = 2 => $\log_{2}1$ = 0 =>S($\frac{m}{2}$) = O(logm)
#
# => T(n) = S(m) = O(loglogn)

# %% [markdown]
# #Bài 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ở lần return cuối, ta thấy hàm mỗi lần đệ quy sẽ chia ra đệ quy 2 nhánh cho tới khi n = 0 =>độ phức tạp là O($2^{n}$)
